# %%
#리스트의 요소 하나 추가하기 
a = [10,20,30]
a.append(500)
print(a)

len(a)

# %%
a=[]
a.append(10)
print(a)

# %%
#리스트안에 리스트 추가하기
a=[10,20,30]
a.append([500,600])
print(a)
len(a)

# %%
#리스트 확장하기
a=[10,20,30]
a.extend([500,600])
print(a)
len(a)

# %%
#리스트에 특정인덱스에 요소 추가하기
a=[10,20,30]
a.insert(2,500)
print(a)

# %%
a=[10,20,30]
a.insert(1,700)
print(a)

# %%
a=[10,20,30]
a.insert(len(a),500) #항상 마지막을 가르킴
print(a)

# %%
a=[10,20,30]
a.insert(1,[500,600])
print(a)

# %%
a=[10,20,30]
a[1:1] = [500,600]
print(a)

# %%
a=[10,20,30]
a[1:2] = [500,600]
print(a)

#위와 다르게 원래들어가있던 20사라짐

# %%
#리스트에서 특정인덱스에 요소 삭제하기 
a=[10,20,30]
print(a.pop()) #꺼내진 마지막값을 출력
print(a)

# %%
a=[10,20,30]
print(a.pop(1))
print(a)

# %%
a=[10,20,30]
del a[1]
print(a)

# %%
#리스트에서 특정값을 찾아서 삭제하기 
a=[10,20,30]
print(a.remove(20)) #해당하는 값으로 지움 #그냥지울뿐 팝처럼 값이 들어가진않음
print(a)

# %%
a=[10,20,30,20]
a.remove(20) #해당하는 값으로 지움 #첫번째것만 지워짐
print(a)

# %%
#리스트에서 특정 값의 인덱스 구하기
a = [10,20,30,15,20,45]
a.index(20)

# %%
#특정값의 개수 구하기 
a = [10,20,30,15,20,45]
a.count(20) #특정값 갯수세려주기

# %%
#리스트의 순서를 뒤집기
a = [10,20,30,15,20,45]
#list(reversad(a))
#list(reversed(a))
a.reverse()
print(a)

# %%
#리스트의 요소 정렬하기
a = [10,20,30,15,20,45]
#a.sort
#sorted
a.sort()
print(a)
a.sort(reverse=True)
print(a)
#print(a[::-1])

# %%
#리스트에 모든 요소를 삭제하기 
a = [10,20,30]
a.clear()
print(a)

# %%
a=[10,20,30]
#del a 
print(a)

# %%
a=[10,20,30]
del a[:]
print(a)

# %%
#리스트를 슬라이스로 조작하기
a= [10,20,30]
a[len(a):] = 500

# %%
a=[10,20,30]
a[len(a):] = [500,600]
print(a)

# %%
#리스트의 할당과 복사하기 
a=[0,0,0,0,0]
b=a

a is b 
print(id(a))
print(id(b))

# %%
b[2] = 99
print(a)
print(b)

# %%
a=[0,0,0,0]
b=a.copy()

a is b 

print(id(a))
print(id(b))

a==b #값만비교

# %%
b[2] = 99
print(a)
print(b)
#복사와 참조구분하기

# %%
#반복문으로 리스트의 요소를 모두 출력하기 
a=[38,21,53,61,19]
for i in a:
    print(i)

# %%
#인덱스와 요소를 함께 출력하기-enumerate()
a=[38,21,53,61,19]

for i in enumerate(a):
    print(i) 
    #키와 벨류를 튜플로가져옴 #키는 서비스

# %%
a=[38,21,53,61,19]

for index,value in enumerate(a):
    print(index,value)

# %%
a=[38,21,53,61,19]

for index,value in enumerate(a, start=1):
    print(index,value)

# %%
#while반복문으로 요소 출력하기
a=[38,21,53,61,19]
i=0
while i < len(a):
    print(a[i])
    i+= 1

# %%
#while반복문으로 요소 출력하기
a=[38,21,53,61,19]
i=0
while i <= len(a):
    print(a[i])
    i+= 1

# %%
#리스트의 가장 작은수, 가장 큰수, 합계 구하기
#가장 작은 수와 가장 큰 수 구하기
a=[38,21,53,61,19]
print(max(a))
print(min(a))
print(sum(a))

# %%
a=[38,21,53,61,19]
smallest=a[0]
for i in a:
    if i <smallest:
        smallest = i

print(smallest)

# %%
a=[38,21,53,61,19]
largest=a[0]
for i in a:
    if i >largest:
        largest = i

print(largest)

# %%
a=[38,21,53,61,19]
a.sort()
print(a)
a[0]

# %%
#요소의 합계 구하기 
a=[10,10,10,10,10]
x = 0
for i in a:
    x+=i #x=x+1
print(x)

# %%
#리스트표현식사용하기 (리스트 컴프리헨션)
##[식 for 변수 in 리스트]
##list(식 for 변수 in 리스트)

# %%
a= []
for i in range(10):
    a.append(i)

print(a)

a=[i for i in range(10)]
print(a)
b= list(i for i in range(10))
print(b)

# %%
c=[i +5 for i in range(10)]
print(c)

# %%
d=  [i*2 for i in range(10)]
print(d)

# %%
#리스트표현식에서 if 조건문 사용하기
a=[]
for i in range(10):
    if i%2 ==0:
        a.append(i)
print(a)

##### 리스트 컴프리핸션
b=[j for j in range(10) if 1%2 ==0 ]
print(b)

# %%
#홀수일때 
b= [i+5 for i in range(10) if i %2 ==1]
print(b)

# %%
b=[]
for i in range(10):
    if i %2 ==1 :
        b.append(i+5)
        #print(i+5)
print(b)

# %%
#for반복문과 if 조건문을 여러번 사용하기 
[i * j for i in range (2,10) for j in range (1,10)]

# %%
#리스트에서 map 사용하기

#list(map(함수,리스트))
#tuple(map(함수,리스트))

a=[1.2,2.5,3.7,4.5]
for i in range(len(a)):
    a[i] = int(a[i])
print(a)

# %%
a=[1.2,2.5,3.7,4.5]
list(map(int,a)) #맵으로 만들어진 개체

# %%
list(map(str,range(10)))

# %%
#input().split()과 맵 
a=input().split()
print(a)
a= list(map(int,a))

# %%
#튜플응용하기 
a=(38,21,53,61,19,53)
a.index(53)
a.count(21)

# %%
a=(38,21,53,61,19,53)
for i in a : 
    print(i)

# %%
a,b = list(map(int,input().split()))
# for i in range(b) :
#     if a<b:     
#         print(a**2)
#         continue
#     else :
#         print("?")

#for반복문과 if 조건문을 여러번 사용하기 
[i * j for i in range (a,b) for j in range (1,10)]

# %%
#2의거듭제곱리스트생성하기
first,second = map(int,input().split())
result=[2**i for i in range(first,second+1)]
result.pop(-2)
result.pop(1)
print(result)

# %%
first,second = map(int,input().split())
result = [2**i for i,val in enumerate(range(first,second+1)) if i!=1 and i ]
print(result)
