# %%
import random

# Yes와 No를 담은 리스트
options = ["Yes", "No"]

# 리스트에서 무작위로 하나를 선택
result = random.choice(options)
print(result)

# result = random.choice(options)

# # 결과 출력
# print(result)
# Out:
# No

# %%
import random

#레인지를 사용하여 리스트 만들기
ran_=range(10)
result = random.choice(ran_)
print(result)

#홀
# Out:
# 6
