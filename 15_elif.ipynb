# %%
# #elif 사용하기
# if 조건식 :
#     수행할코드1
# elif 조건식2:
#     수행할코드2
# else :
#     수행할코드3

# %%
x=15
if x== 10:
    print("10입니다")
elif x==20:
    print("20입니다")

# %%
x=30
if x ==10:
    prrint("10입니다")
elif x ==20: 
    print("20입니다")
else:
    print("10도 20도 아닙니다")
# Out:
# 10도 20도 아닙니다

# %%
x=30
if x ==10:
    prrint("10입니다")
else:
    print("10도 20도 아닙니다")

elif x ==20: 
    print("20입니다")
#else가 끝에 와야함
# Out:
#   Cell In[5], line 7
#     elif x ==20:
#     ^
# SyntaxError: 'elif' block follows an 'else' block

# %%
button=int(input())

if button == 1:
    print("콜라")
elif button == 2:
    print("사이다")
elif button==3:
    print("환타")
else:
    
    print("제공하지않는메뉴")
# Out:
# 제공하지않는메뉴

# %%
x=int(input())

if 11<=x<=20:
    print("11~20")

elif 21<=x<=30:
    print("21~30")
else :
    print("아무것도해당하지않음")
# Out:
# 11~20

# %%
age=int(input())
money=9000
if 7<=age<=12 : 
    money=money-650
    print(money)
elif 13<=age<=18 :
    money=money-1050
    print(money)
elif 19<=age:
    money=money-1250
    print(money)
else:
    print("너무어립니다")
# Out:
# 7750

# %%
age=int(input())
balance = 9000

if age >=7:
    if age>= 7 and age<=12:
        print(balance-650)
    elif 13<=age<18:
        print(balance-1050)
    else:
        print(balance-1250)
    
else :
    print("잘못된입력입니다")
# Out:
# 7750
