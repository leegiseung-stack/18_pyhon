# %%
True
False

#첫글자는 반드시 대문자
# Out:
# True

# %%
#비교연산자
3 > 1
# Out:
# True

# %%
#숫자가 같은지 다른지 비교
print(10==10)
print(10!=5) #!은 아니다(다르다) 뜻
# Out:
# True
# True

# %%
print("pyrthon"=="pyrthon")
print("pyrthon"=="PYRTHON")
# Out:
# True
# False

# %%
#부등호사용 
print(10>20) 
print(10<20) 
print(10>=20) 
print(10<=20)
# Out:
# False
# True
# False
# True

# %%
print(1==1.0)
#print(1 is 1.0) #같은주소를 가르치고 있는지 물어보는것
print(id(1))
print(id(1.0))
# Out:
# True
# 140730032186488
# 1513071945168

# %%
#논리연산자 사용하기
print(True and True)
print(True and False)
print(False and False)
print(False and True)
# Out:
# True
# False
# False
# False

# %%
print(True or True)
print(True  or  False)
print(False  or  False)
print(False  or  True)
# Out:
# True
# True
# False
# True

# %%
#not true 결과값을 뒤집어준다 True -> False / False->True

not True and False or not False
False and False or True
False or True 
True 

#낫 연산자를 먼저 연산하고 논리연산자를 먼저 연산

#애매하면 괄호 치세요! 
(not True) and (False) or (not False)
# Out:
# True

# %%
#논리연산자와 비교연산자 함께 사용하기
print(10 == 10 and 10 !=5)
print(10 == 10 and 10 !=5)

True and True
#파이썬은 and가 나중에계산되지만 데이터베이스할때는 and가 먼저계산됨
#괄호하는 버릇을 들이세요
# Out:
# True
# True

# %%
print(10 == 10 and 10 !=5)
print(10>5 or 10<3)
print(not 10 > 5)
# Out:
# True
# True
# False

# %%
not 10
# Out:
# False

# %%
False > 5
# Out:
# False

# %%
print(not 1 is 1.0 )
# Out:
# True
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_20544\325491013.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(not 1 is 1.0 )

# %%
korean=92
english=47
mathematics = 86
science = 81

합격여부=((korean>=50) and (english>=50) and (mathematics>=50) and (science>=50) )
if 합격여부 == True:
    print("합격입니다")
elif 합격여부 ==False:
    print("불합격입니다")
# Out:
# 불합격입니다
