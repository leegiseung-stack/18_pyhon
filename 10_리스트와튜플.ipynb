# %%
#리스트만들기(대괄호)
a=[38,21,53,62,19]
print(a)

# %%
person = [
    "jamese",17,175.3,True
]
print(person)

# %%
#빈리스트 만들기
a= []
n=list()

#int()
#float()
#str()
#bool()

print(a)
print(n)

# %%
import random

#레인지를 사용하여 리스트 만들기
ran_=range(10)
result = random.choice(ran_)
print(result)

# %%
range(10)
list(range(10))

# %%
list(range(5,12))

# %%
list(range(-4,10,2))
#list(range(-4,10,-1))

# %%
list(range(10,1,-1))

# %%
#튜플사용하기
a = (38,21,53,62,19)
b = 38,21,53,62,19

print(a)
print(b)

# %%
a=[1]
b=(1,)
c=(1)

type((a))
type((b))
type((c))

# %%
person = (
    "jamese",17,175.3,True
)
print(person)

# %%
#요소가 한개 들어있는 튜플만들기 
(38)
(38,)

# %%
#range를 사용하여 튜플 만들기 
range(10)

# %%
tuple(range(10))

# %%
tuple(range(5,12))

# %%
#튜플을 리스트로 만들고 리스트를 튜플로 만들기
a=[1,2,3] #a는리스트객체
a=tuple(a) #재할당시켜야 바뀜. 아예 다른변수를써도좋음
type(a)

b=(4,5,6)
b=list(b) #b에 재할당8ㅕㅓ
type(b)

# %%
a=list(range(5,-10,-2))
print(a)

# %%
숫자=int(input())
a=list(range(-10,10,숫자))
print(a)
