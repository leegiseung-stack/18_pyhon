# %%
#사칙연산
print(1 + 1) 
print("1"+"1")

# %%
#소숫점이하를 버리는 연산자 // (몫을 구하는 연산자)
print(6 // 2) #(몫)
print(4 // 2)

# %%
#나머지를 구하는 연산자 % 
5 % 2 
7 % 3

# %%
# 거듭제곱을 구하는 **연산자 
2 ** 10
10 ** 10

# %%
# 값을 정수로 만들기 
int(3.3)
int(5/2)
int("1")

# %%
#객체의 자료형 알아내기
#type()

type(10)
type("1")

# %%
#실수계산하기
3.5+2.1

# %%
#실수와 정수를 함께 계산하면 
type(4.2+5)

# %%
#값을 실수로 만들기
print(float(5))
print(float(1+2))
print(float(5.3))
print(float(1+2))
print(float(1+2))

# %%
#괄호사용하기 
35+1*2
(35+1)*2

# %%
10/4

# %%
#0.2467 * 도로와의거리 (m) +4.159
int(0.2467*12+4.159)

# %%
#ap*0.6 +225 
print(102*0.6+225)
