# %%
##sep로 값 사이에 문자 넣기
print(1,2,3)
print(1,2,3,sep=",")

# %%
print("hello","python")
print("hello","python",sep="")

# %%
print(1920,1080,sep="x")

# %%
#줄바꿈 활용
print(1,2,3)
print(1,2,3, sep="\n") #\n줄바꿈

# %%
print("1\n2\n3")

# %%
## end 사용하기
print(1)
print(2)
print(3)

# %%
print(1,end="")
print(1,end="")
print(1,end="")

# %%
print(1,end="HAPPY")
print(1,end="HAPPY")
print(1,end="HAPPY")

# %%
year = 2000
month = 10
day = 27
hour = 11
minute = 43
second = 59

print(year,month,day,sep="/",end=" ")
print(hour,minute,second,sep=":")

# %%
year,month,day,hour,minute,second = input("공백으로 입력하세요").split()
print(year,month,day,sep="-",end="T")
print(hour,minute,second,sep=":")

# %%
print(3.1);
