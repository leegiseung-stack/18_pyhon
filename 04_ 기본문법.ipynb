# %%
#세미콜론
print("hello world");

# %%
print("hello") ; print("1234")

# %%
#한줄주석 
#출력하라
print("hello world")

# %%
#블록주석
# print(".hello world")
# print("hello world")
# print("hello world")

# %%
#들여쓰기
a=5
if a == 10:
    print("10입니다")
    print("5입니다")

# %%
#입력값을 변수에 저장하기 
##input함수 사용하기
input()

# %%
##input함수에 결과를 변수에 할당
a= input()
print(a)

# %%
x=input("문자열을입력하세요")
print(x)
