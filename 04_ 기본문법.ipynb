# %%
#세미콜론
print("hello world");
# Out:
# hello world

# %%
print("hello") ; print("1234")
# Out:
# hello
# 1234

# %%
#한줄주석 
#출력하라
print("hello world")
# Out:
# hello world

# %%
#블록주석
# print(".hello world")
# print("hello world")
# print("hello world")

# %%
#들여쓰기
a=5
if a == 10:
    print("10입니다")
    print("5입니다")
