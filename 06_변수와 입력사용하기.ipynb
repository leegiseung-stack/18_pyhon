# %%
#변수만들기
x=10 
## 1.영문 문자와 숫자사용
## 2.대소문자 구분
## 3.문자부터 시작해야 함
## 4._(밑줄 문자)로 시작할수있음
## 5.특수문자 (+,-,*,/,$,@,%)등 사용할 수 없음
## 6. 파이썬키워드(if,for,while,and,or)변수로 사용할수없음

# %%
x=10
print(x)
# Out:
# 10

# %%
print = 100 ;
##숫자형의 오브젝트라서 못씀 

del print
print ("hello world")

hello_world ="hi" #스네이크케이스 snake case
helloWorld = "hi" #카멜케이스 camel case
HelloWorld ="hi" #파스칼케이스 pascal case
# Out:
# hello world

# %%
#변수의 자료형 알아내기 
print(x)
type(x)
# Out:
# 10
# int

# %%
y="hello world"
type(y)
# Out:
# str

# %%
#변수 여러 개를 한 번에 만들기
x,y,z=10,20,30
print(x)
print(y)
print(z)
# Out:
# 10
# 20
# 30

# %%
x,y,z =10,20,"가나다"

# %%
x=y=z=10
print(z)
x=20
print(x)
print(z)
# Out:
# 10
# 20
# 10

# %%
x,y =10,20
print(x,y)
x,y=y,x
print(x,y)
# Out:
# 10 20
# 20 10

# %%
#변수로 계산하기 
a=10 
b=20
c=a+b 
print(c)
# Out:
# 30

# %%
#산술연산후 할당 연산자 사용하기 
a=10 
a+20 
print(a)
# Out:
# 10

# %%
a=10 
a= a+20 #재할당
print(a)

a=10
a+=20
print(a)

#위의 구문과 똑같음
# Out:
# 30
# 30

# %%
#두 숫자의 합 구하기 
a= input("첫번째 숫자를 입력하세요")
b = input("두번째 숫자를 입력하세요")
print(type(a))
print(type(b))
print(a+b)
# Out:
# <class 'str'>
# <class 'str'>
# 1020

# %%
a= int(input("첫번째 숫자를 입력하세요"))
b = int(input("두번째 숫자를 입력하세요"))
print(type(a))
print(type(b))
print(a+b)
# Out:
# <class 'int'>
# <class 'int'>
# 30
