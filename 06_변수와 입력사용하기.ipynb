# %%
#변수만들기
x=10 
## 1.영문 문자와 숫자사용
## 2.대소문자 구분
## 3.문자부터 시작해야 함
## 4._(밑줄 문자)로 시작할수있음
## 5.특수문자 (+,-,*,/,$,@,%)등 사용할 수 없음
## 6. 파이썬키워드(if,for,while,and,or)변수로 사용할수없음

# %%
x=10
print(x)
# Out:
# 10

# %%
print = 100 ;
##숫자형의 오브젝트라서 못씀 

del print
print ("hello world")

hello_world ="hi" #스네이크케이스 snake case
helloWorld = "hi" #카멜케이스 camel case
HelloWorld ="hi" #파스칼케이스 pascal case
# Out:
# hello world

# %%
#변수의 자료형 알아내기 
print(x)
type(x)
# Out:
# 10
# int

# %%
y="hello world"
type(y)
# Out:
# str

# %%
#변수 여러 개를 한 번에 만들기
x,y,z=10,20,30
print(x)
print(y)
print(z)
# Out:
# 10
# 20
# 30

# %%
x,y,z =10,20,"가나다"

# %%
x=y=z=10
print(z)
x=20
print(x)
print(z)
# Out:
# 10
# 20
# 10

# %%
x,y =10,20
print(x,y)
x,y=y,x
print(x,y)
# Out:
# 10 20
# 20 10

# %%
#변수로 계산하기 
a=10 
b=20
c=a+b 
print(c)
# Out:
# 30

# %%
#산술연산후 할당 연산자 사용하기 
a=10 
a+20 
print(a)
# Out:
# 10

# %%
a=10 
a= a+20 #재할당
print(a)

a=10
a+=20
print(a)

#위의 구문과 똑같음
# Out:
# 30
# 30

# %%
#두 숫자의 합 구하기 
a= input("첫번째 숫자를 입력하세요")
b = input("두번째 숫자를 입력하세요")
print(type(a))
print(type(b))
print(a+b)
# Out:
# <class 'str'>
# <class 'str'>
# 1020

# %%
a= int(input("첫번째 숫자를 입력하세요"))
b = int(input("두번째 숫자를 입력하세요"))
print(type(a))
print(type(b))
print(a+b)
# Out:
# <class 'int'>
# <class 'int'>
# 30

# %%
#입력값을 변수 두개에 저장하기 
a=input("문자열 두개를 입력하세요")
print(a)
a.split() #문자열의 형태를 띄고있어서 스플릿함수사용가능 
print(a)
# Out:
# hello python

# %%
a,b=input("문자열 두개를 입력하세요").split() 
#a,b=input("문자열 두개를 입력하세요")이 문자열이므로 스플릿사용가능 
print(a)
print(b)
# Out:
# hello
# world

# %%
a,b = 10, 20 #튜플이라서 생략되면서 가능함

# %%
#두숫자의 합 구하기
a, b = input("숫자 두 개를 입력하세요!").split()

#print(a + b)

a=int(a) 
b=int(b)
print(a+b)
# Out:
# 30

# %%
#map을 사용하여 정수로 변환하기
a,b = map(int,["10","20"])
print(a)
print(b)
print("=======================")
print(type(a))
print(type(b))
# Out:
# 10
# 20
# ...
# <class 'int'>
# <class 'int'>

# %%
a,b= map(int,input("숫자 두개를 입력하세요").split())
print(a+b)
# Out:
# 30

# %%
#입력받은 값을 콤마를 기준으로 분리하기 
"10,20".split(",")
# Out:
# ['10', '20']

# %%
"10,20".split()
# Out:
# ['10,20']

# %%
a,b= map(int,input("숫자 두개를 입력하세요").split(","))
print(a)
print(b)
# Out:
# 10
# 20

# %%
a,b,c = map(int,input("숫자3개 입력하세요 공백으로").split())
print(a,b,c)
print(a+b+c)
# Out:
# 10 20 30
# 60

# %%
a=input()
b=input()
c=input()
print(a)
print(b)
print(c)
# Out:
# 50
# 100
# none

# %%
국어,영어,수학 =map(int,input().split())
합계=국어+영어+수학
평균=합계/3
print(국어,영어,수학)
print(평균)
# Out:
# 100 100 100
# 100.0

# %%
국어=int(input("국어점수입력"))
수학=int(input("수학점수입력"))
영어=int(input("영어점수입력"))
print(국어)
print(수학)
print(영어)
# Out:
# 100
# 100
# 100

# %%
국어,영어,수학 =map(int,input().split())
합계=국어+영어+수학
평균=합계/3
print(국어,영어,수학)
print(평균)
