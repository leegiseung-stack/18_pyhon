# %%
#if의 조건문 사용하기
#if 조건식 : 
#   코드
# 

x=10
if x == 10:
    print("10입니다")
# Out:
# 10입니다

# %%
#if조건문을 사용할 때 주의할점
#if x =10;#대입이라서 비교연산x 실행이안됨

# %%
#if 조건문에서 코드를 생략하기
x=10
if x==3:
    pass
else : print("ㅇ")
# Out:
# ㅇ

# %%
# if 조건문과 들여쓰기 
x = 10 
if x==10:
    print("x에 들어있는 숫자는")
    print("10입니다.")

# %%
#중첩 if조건문 사용하기
x=15
if x >= 10:
    print("10이상입니다")
    if x == 15:
        print("15입니다")

    if x == 20:
        print("20입니다")
# Out:
# 10이상입니다
# 15입니다

# %%
#사용자가 입력한 값에 if 조건문 사용하기 
x=int(input())

if x ==10:
    print("10입니다")

if x == 20:
    print("20입니다")
# Out:
# 10입니다

# %%
x=5
if x!=10 :
    print("OK")
# Out:
# OK

# %%
cash3000=int(input("3000원캐시쿠폰"))
cash5000=int(input("5000원캐시쿠폰"))

cash=int(input("금액"))

if cash3000 != 0:
    cash3000=cash3000*3000
    cash=cash-cash3000

if cash5000 !=0:
    cash5000=cash5000*5000
    cash=cash-cash5000

print(cash)
# Out:
# 2000

# %%
number = int(input())
coupon = input()

sale=coupon[-4:]
print(number)
print(sale)

if type(sale) != int:
    sale = int(sale)
if type(number) != int:
    number =int(number)

print(int(number - sale))
# Out:
# 10000
# 8000
# 2000

# %%
# #else사용하기
# if 조건식:
#     수행할코드1
# else : 
#     수행할코드2

x=5 
if x ==10:
    print("10입니다")
else: 
    print("10이아닙니다")
# Out:
# 10이아닙니다

# %%
#else와 들여쓰기

x=5 
if x ==10:
    print("10입니다")
else: 
    print("10이아닙니다")

# %%
x=5 
if x ==10:
    print("10입니다")
else: 
    print("x에들여있는 숫자는")
    print("10이아닙니다")

    #수행할코드는 같은라인에 적어야한다
# Out:
# x에들여있는 숫자는
# 10이아닙니다

# %%
x=5 
if x ==10:
    print("10입니다")
else: 
    print("x에들여있는 숫자는")
    
print("10이아닙니다")
# Out:
# x에들여있는 숫자는
# 10이아닙니다

# %%
#if조건문에 동작방식 알아보기
if True: 
    print("참")
else: 
    print("거짓")

if False:
    print("참")
else:
    print("거짓")

if None :
    print("참")
else :
    print("거짓")
# Out:
# 참
# 거짓
# 거짓

# %%
#조건문에 숫자 지정하기

if 0:
    print("참")
else :
    print("거짓")

if 1:
    print("참")
else:
    print("거짓")

if 0x1f:
    print("참")
else :
    print("거짓")

if 0b1000:
    print("참")
else :
    print("거짓")

if 13.5 : 
    print("참")
else :
    print("거짓")

    #0이 아닌 모든 숫자는 참이다!
# Out:
# 거짓
# 참
# 참
# 참
# 참

# %%
#if 조건문에 문자열 지정하기
#빈문열일 경우만 거짓 False 
if "hello" : 
    print("참")
else:
    print("거짓")

if "":
    print("참")
else :
    print("거짓")

if " ":
    print("참")
else :
    print("거짓")
# Out:
# 참
# 거짓
# 참

# %%
#조건식을 여러개 지정하기
x=10
y=20

if x==10 and y==20:
    print("참")
else :
    print("거짓")
# Out:
# 참

# %%
#중첩 if 조건문과 논리연산자

x=10
if x >0:
    if x <20:
        print("20보다작은 양수입니다")


#########################################

x=10

if x>0 and x<20:
    print("20보다작은 양수입니다")

########################################
if 0 < x <20 :
    print("20보다 작은 양수입니다")
# Out:
# 20보다작은 양수입니다
# 20보다작은 양수입니다

# %%
written_test = 75
coding_test = True

if written_test>=80 and coding_test==True :
    print("합격")
else : print ("불합격")
# Out:
# 불합격

# %%
국어,영어,수학,과학 = map(int,input().split())

평균=(국어+영어+수학+과학)/4

if 국어>100 or 국어<0 :
    print("잘못된점수입니다")
if 영어>100 or 영어<0 :
    print("잘못된점수입니다")
if 수학>100 or 수학<0 :
    print("잘못된점수입니다")
if 과학>100 or 수학<0 :
    print("잘못된점수입니다")

if 평균>=80 : 
    print("합격입니다")
else : 
    print("불합격입니다")
# Out:
# 잘못된점수입니다
# 불합격입니다

# %%
국어,영어,수학,과학 = list(map(int,input().split()))

평균=(국어+영어+수학+과학)/4

if 국어>100 or 국어<0 :
    print("잘못된점수입니다")
if 영어>100 or 영어<0 :
    print("잘못된점수입니다")
if 수학>100 or 수학<0 :
    print("잘못된점수입니다")
if 과학>100 or 수학<0 :
    print("잘못된점수입니다")



if 평균>=80 : 
    print("합격입니다")
else : 
    print("불합격입니다")
# Out:
# 불합격입니다

# %%
국어,영어,수학,과학=map(int,input().split())

if 0<=국어<=100 or 0<=영어<=100 or 0<=수학<=100 or 0<=과학<=100:
    avg=(국어+영어+수학+과학)/4
    if avg>80:
        print("합격")
    else : 
        print("불합격")
else :
    print("잘못된 점수")
# Out:
# 불합격
