# %%
#문자열 사용 
hello = "hello World"
print(hello)

# %%
hello = '안녕하세요'
hello

# %%
hello='''hello,python'''
hello

# %%
python = """python programming"""
python

# %%
#여러줄로된 문자열 사용하기
hello="""hello, world
안녕하세요
Python입니다"""
hello

# %%
hello='''hello, world
안녕하세요
Python입니다'''

# %%
#문자열안에 작음따옴표 큰 따옴표 포함하기 
s= "python isn's difficult"

# %%
s= 'he said "python is easy"'
print(s)

# %%
sigle_quote="""

"안녕하세요". '파이썬 입니다.'

"""
print(sigle_quote)

# %%
s="""Python is a programming language that lets you work quickly 
and 
integreate system more effectively"""

print(s)

# %%
s=""" 
    'python' is a "programming language" 
    that lests you work quickly
    and 
    inttegrate systems more effectively.
"""

print(s)

# %%
import random

# Yes와 No를 담은 리스트
options = ["Yes", "No"]

# 리스트에서 무작위로 하나를 선택
result = random.choice(options)
print(result)
