# %%
#문자열 바꾸기
a= "Hello World"
a= a.replace("World","python")
print(a)

# %%
"가나다라마바사".replace("가나다라","12345")

# %%
#문자 바꾸기 
table = str.maketrans("aeiou","12345")
"apple".translate(table)

# %%
a= str.maketrans("가나다라마바사아","12345678")
"가하하하하하아하하하하하하".translate(a)

# %%
#문자열분리하기
"apple pear grape pineapple orange".split()

# %%
"apple pear grape pineapple orange".replace(" ",",")
"apple pear grape pineapple orange".split(",")

# %%
#구분자 문자열과 문자열 리스트 연결하기
" ".join(['apple', 'pear', 'grape', 'pineapple', 'orange'])

# %%
"-".join(['apple', 'pear', 'grape', 'pineapple', 'orange'])

# %%
#소문자를 대문자로 바꾸기 
"python".upper()

# %%
#대문자를 소문자로 바꾸기 
'PYTHON'.lower()

# %%
#공백삭제하기 
## 왼쪽 
"     python     ".lstrip()

# %%
##오른쪽
"     python     ".rstrip()

# %%
#양쪽
"     python     ".strip()

# %%
#특정문자삭제하기
", python.  ".strip(",.")

# %%
", python.  ".strip() #공백지우기

# %%
".  , python.,  ".strip(",.").strip().strip(",.")

# %%
#문자열을 왼쪽 정렬하기
"python".ljust(10)
"python".rjust(10)

# %%
#문자열을 가운데 정렬하기
"python".center(11)

# %%
#문자열 왼쪽에 0을 채우기 
"35".zfill(4)

# %%
"3.5".zfill(6)

# %%
"hello".zfill(10)

# %%
#문자열위치찾기
"apple pineapple".find("pl")  #인덱스값을출력

# %%
"apple pineapple".rfind("pl")  #인덱스값을출력

# %%
"apple pineapple".index("pl")  #인덱스값을출력

# %%
"apple pineapple".rindex("pl")  #인덱스값을출력

# %%
#인덱스는 없는글자를 찾을때 에러 find는 없는글자찾을때 -1 
#가능하면 find를사용하는것이 좋음

# %%
#문자열갯수세기
"apple pineapple".count("pl")  
"apple pineapple".count("p")

# %%
#문자열 서식지정자와 포멧팅 사용하기
#서식 지정자로 문자열 넣기 
#%s % "문자열"
"I am %s" % "james" 
name="maria"
"i am %s" % name

# %%
#서식 지정자로 숫자 넣기 
#"%d" % 숫자
"I am %d" %20

b = 20
"I am %d" %b

# %%
#서식지정자로 소수점 표현하기
#"%f % 숫자(실수)"
"%f" % 2.3

# %%
#"%.자리수 f" %숫자 
"%.2f"  %2.3

"%5.2f"  %2.3

# %%
#서식지정자로 문자열 정렬하기
#%길이s 

"%10s" % "python"

# %%
#문자열 왼쪽 정렬하기 
"%-10s" % "python"

# %%
#서식 지정자로 문자열 안에 값 여러개 넣기
# "%d %s" % (숫자,문자)
"today is %d %s" % (3, "Aapril")

# %%
#format 매서트 사용하기
print("hello, {0}".format("wrold"))

# %%
#format메서드로 값을 여러개 넣기
print("hello {0} {2} {1}".format("python","script", 3.6))

# %%
#format 메서드로 같은 값을 여러개 넣기
print("{0} {0} {1} {1}".format("python","script"))

# %%
#format 매서드에서 인덱스 생략하기
print("Hello {} {} {}".format("python","script",3.6))

# %%
#format매서드에서 인덱스대신 이름 지정해주기
print("Hello {language} {version}".format(language="python",version=3.6))

# %%
#문자열 포멧팅에 변수를 그대로 사용하기 
language= "python"
version = 3.6
print(f"Hello {language} {version}")

# %%
#format 매서드로 문자열 정렬하기 
#"{인덱스:<10}.format("python")
print("{0<10}",format("python"))

# %%
print("{0<10}",format("python"))

# %%
#숫자개수 맞추기
#"%0개수d % 숫자"
#"{인덱스:0개수d}".format(숫자)
print("%03d" %1)
print("%d" %1)
print("{:03d}".fromat(35))

# %%
print("%f"%3.6)
print("%08.2f"%3.6)
print("{:.2f}".format(150.37))
print("{:08.2f}".format(150.37))

# %%
#채우기와 정렬을 조합해서 사용하기 
print("{:0<10}".format(15))
print("{:0>10}".format(15))

# %%
number = 3.6
print(f"{number:010.2f}")

# %%
path = 'c:\\user\\dojang\\appdata\\Local\\programs\\python\\python36-32\\python.exe'
x=path.split('\\')
filename = x[-1]
print(filename)

# %%
#천단위 구분기호 
number = 30000
print(f"{number:,.2f}")

# %%
a="""
“Exactly. One much requires from each one the duty which each one can perform,” the king went on. “Accepted authority rests first of all on reason. If you ordered your people to go and throw themselves into the sea, they would rise up in revolution. I have the right to require obedience because my orders are reasonable.”
“Then my sunset?” the little prince reminded him: for he never forgot a question once he had asked it.
“You shall have your sunset. I shall command it. But, according to my science of government, I shall wait until conditions are favorable.”
“When will that be?” inquired the little prince. “Hum! Hum!” replied the king, and before saying anything else he consulted a bulky almanac. “Hum! Hum! That will be about… about… that will be this evening about twenty minutes to eight. And you will see how well I am obeyed.”
The little prince yawned. He was regretting his lost sunset. And then, too, he was already beginning to be a little bored. “I have nothing more to do here,” he said to the king. “So I shall set out on my way again.” “Do not go,” said the king, who was very proud of having a subject. “Do not go. I will make you a Minister!” “Minister of what?” “Minster of…of Justice!” “But there is nobody here to judge!” “We do not know that,” the king said to him. “I have not yet made a complete tour of my kingdom. I am very old. There is no room here for a carriage. And it tires me to walk.” “Oh, but I have looked already!” said the little prince, turning around to give one more glance to the other side of the planet.
On that side, as on this, there was nobody at all… “Then you shall judge yourself,” the king answered, “that is the most difficult thing of all. It is much more difficult to judge oneself than to judge others. If you succeed in judging yourself rightly, then you are indeed a man of true wisdom.”
“Yes,” said the little prince, “but I can judge myself anywhere. I do not need to live on this planet.
“Hum! Hum!” said the king. “I have good reason to believe that somewhere on my planet there is an old rat. I hear him at night. You can judge this old rat. From time to time you will condemn him to death. Thus his life will depend on your justice. But you will pardon him on each occasion; for he must be treated thriftily. He is the only one we have.”
“I,” replied the little prince, “do not like to condemn anyone to death. And now I think I will go on my way.” “No,” said the king. But the little prince, having now completed his preparations for departure, had no wish to grieve the old monarch. “If Your Majesty wishes to be promptly obeyed,” he said, “he should be able to give me a reasonable order. He should be able, for example, to order me to be gone by the end of one minute. It seems to me that conditions are favorable…” As the king made no answer, the little prince hesitated a moment.
Then, with a sigh, he took his leave. “I made you my Ambassador,” the king called out, hastily.
He had a magnificent air of authority.
“The grown-ups are very strange,” the little prince said to himself, as he continued on his journey.
"""
count = a.split().count("the")
print("the만카운트",count)
print("the포함된단어모두카운드",a.count("the"))

# %%
a=map(int,input().split(";"))

# %%
path = 'c://user//dojang//appdata//Local//programs//python//python36-32//python.exe'
path.split("/")

# %%
lis = map(int,input().split(";"))
for i in sorted(lis,reverse=True):
    print(f"{i:9,}")

# %%
lis = list(map(int,input().split(";")))

lis.sort(reverse=True)
for i in lis:
    print(f"{i:9,}")
