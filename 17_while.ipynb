# %%
#while반복문 사용하기 
# 초기식
# while 조건식:
#     반복할코드
#     변화식

i = 0

while i<10:
    print("hello world",i)
    i+=1 #i=i+1

# %%
i=1
while i <=5:
    print("hello world",i)
    i=i+1

# %%
#초기값을 감소시키기
i=5
while i>0 :
    print("hello",i)
    i-=1 #i=i-1

# %%
count = int(input())
i=0 
while i< count :
    print("hello",i)
    i+=1

# %%
#반복횟수가 정해지지 않은 경우
import random 
int(random.random()*10)
random.randint(1,46)

# %%
#반복횟수가 정해지지 않은 경우
import random 
for i in range(6) :
    print(random.randint(1,46))

# %%
import random
i=0
while i !=3:
    i=random.randint(1,6)
    print(i)

# %%
i=2
j=5
while i<32 or j>=1:
    print(i,j)
    i=i*2
    j=j-1

# %%
i=int(input())

while i>=1350 :
    i=i-1350
    print(i)

# %%
bal = int(input())
fare = 1350
while bal>=fare:
    bal -=fare
    print(bal)
